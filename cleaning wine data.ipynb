# %%
import pandas as pd

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# cd drive/My\ Drive/Project\ 3\ -\ Wine\ Quality

# %%
# Import Wine Data
wine_data = pd.read_csv('data/winemag-data-130k-v2.csv')
wine_data.head()
# Out:
#    ID   country                                        description  \
# 0   0     Italy  Aromas include tropical fruit, broom, brimston...
# 1   1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2   2        US  Tart and snappy, the flavors of lime flesh and...
# 3   3        US  Pineapple rind, lemon pith and orange blossom ...
# 4   4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
wine_data.variety.nunique()
# Out:
# 707

# %%
# drop columns 'region_1', 'region_2', 'taster_name', 'taster_twitter_handle'
wine_data = wine_data.drop(columns =['region_1', 'region_2', 'taster_name', 'taster_twitter_handle'])
wine_data.head()
# Out:
#    ID   country                                        description  \
# 0   0     Italy  Aromas include tropical fruit, broom, brimston...
# 1   1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2   2        US  Tart and snappy, the flavors of lime flesh and...
# 3   3        US  Pineapple rind, lemon pith and orange blossom ...
# 4   4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#                                                title         variety  \
# ...

# %%
# drop rows with null values
wine_data = wine_data.dropna()
wine_data.head()
# Out:
#    ID   country                                        description  \
# 1   1  Portugal  This is ripe and fruity, a wine that is smooth...
# 3   3        US  Pineapple rind, lemon pith and orange blossom ...
# 4   4        US  Much like the regular bottling from 2012, this...
# 5   5     Spain  Blackberry and raspberry aromas show a typical...
# 6   6     Italy  Here's a bright, informal red that opens with ...
#
#                           designation  points  price           province  \
# 1                            Avidagos      87   15.0              Douro
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
# 5                        Ars In Vitro      87   15.0     Northern Spain
# 6                             Belsito      87   16.0  Sicily & Sardinia
#
#                                                title             variety  \
# ...

# %%
len(wine_data)
# Out:
# 86148

# %%
# export to csv
wine_data.to_csv('data/wine_data_cleaned.csv', index=False)

# %% [markdown]
# # Condense Variety Types Red

# %%
# Import Wine Data with Color
df_cleaning_red = pd.read_csv('data/wine_data_cleaned_with_color.csv')
df_cleaning_red.head()
# Out:
#       ID    country                                        description  \
# 0  89478    Austria  Wet earth, rain-wet stones, damp moss, wild sa...
# 1  36531   Portugal  This Port was “rescued” from the darkest reces...
# 2  41441   Portugal  This was a great vintage Port year, and this w...
# 3  88870      Italy  Biondi-Santi performs exceptionally well in el...
# 4  56953  Australia  This inky, embryonic wine deserves to be cella...
#
#                designation  points  price         province  \
# 0  Ried Loibenberg Smaragd      94   1100           Wachau
# 1        90-year Old Tawny      97   1000             Port
# 2           Colheita White      94    980             Port
# 3                  Riserva      94    900          Tuscany
# 4                   Grange      99    850  South Australia
#
#                                                title            variety  \
# 0  Emmerich Knoll 2013 Ried Loibenberg Smaragd Gr...   Grüner Veltliner
# ...

# %%
# Create dataframe of only reds
df_cleaning_red = df_cleaning_red[df_cleaning_red["Color"] != 'White']
df_cleaning_red = df_cleaning_red[df_cleaning_red["Color"] != 'Blush']
df_cleaning_red.head()
# Out:
#       ID    country                                        description  \
# 1  36531   Portugal  This Port was “rescued” from the darkest reces...
# 2  41441   Portugal  This was a great vintage Port year, and this w...
# 3  88870      Italy  Biondi-Santi performs exceptionally well in el...
# 4  56953  Australia  This inky, embryonic wine deserves to be cella...
# 5  77028  Australia  This has all the size and weight you've come t...
#
#          designation  points  price         province  \
# 1  90-year Old Tawny      97   1000             Port
# 2     Colheita White      94    980             Port
# 3            Riserva      94    900          Tuscany
# 4             Grange      99    850  South Australia
# 5             Grange      98    850  South Australia
#
#                                                title            variety  \
# 1      W. & J. Graham's NV 90-year Old Tawny  (Port)               Port
# ...

# %%
# duplicate 'variety' column
df_cleaning_red['variety generic'] = df_cleaning_red['variety']
df_cleaning_red.head()
# Out:
#       ID    country                                        description  \
# 1  36531   Portugal  This Port was “rescued” from the darkest reces...
# 2  41441   Portugal  This was a great vintage Port year, and this w...
# 3  88870      Italy  Biondi-Santi performs exceptionally well in el...
# 4  56953  Australia  This inky, embryonic wine deserves to be cella...
# 5  77028  Australia  This has all the size and weight you've come t...
#
#          designation  points  price         province  \
# 1  90-year Old Tawny      97   1000             Port
# 2     Colheita White      94    980             Port
# 3            Riserva      94    900          Tuscany
# 4             Grange      99    850  South Australia
# 5             Grange      98    850  South Australia
#
#                                                title            variety  \
# 1      W. & J. Graham's NV 90-year Old Tawny  (Port)               Port
# ...

# %%
print(df_cleaning_red['variety generic'].nunique())
# Out:
# 323

# %%
df_cleaning_red.loc[df_cleaning_red['variety generic'].str.contains('Red Blend', case=False), 'variety generic'] = 'Red Blend'
print(df_cleaning_red['variety generic'].nunique())
df_cleaning_red['variety generic'].unique()
# Out:
# 319
# array(['Port', 'Sangiovese Grosso', 'Shiraz', 'Sangiovese', 'Carignan',
#        'Syrah', 'Pinot Noir', 'Cabernet Sauvignon',
#        'Tempranillo-Cabernet Sauvignon', 'Nebbiolo', 'Red Blend',
#        'Corvina, Rondinella, Molinara', 'Ramisco', 'Merlot', 'Tinto Fino',
#        'Portuguese Red', 'Tempranillo Blend', 'Malbec', 'Garnacha',
#        'Pinotage', 'Cabernet Blend', 'Pedro Ximénez', 'Tinta de Toro',
#        'Prugnolo Gentile', 'Carmenère', 'Grenache', 'Shiraz-Viognier',
#        'Nerello Mascalese', 'Gamay', 'Tinto del Pais', 'Tannat',
#        'Petit Verdot', 'Spätburgunder', 'Aglianico', 'Cabernet Franc',
#        'Malbec-Cabernet Sauvignon', 'Malbec-Cabernet', 'Francisa',
#        'Rosenmuskateller', 'Mission', 'Alicante Bouschet',
#        'Cabernet-Shiraz', 'Pinot Nero', 'Graciano', 'Petite Verdot',
#        'Pinot Meunier', 'Touriga Nacional Blend', 'Claret',
#        'Cabernet Sauvignon-Malbec', 'Mataro', 'Marzemino',
# ...

# %%
df_cleaning_red.loc[df_cleaning_red['variety generic'].str.contains('Baga-Touriga Nacional', case=False), 'variety generic'] = 'Other'
print(df_cleaning_red['variety generic'].nunique())
df_cleaning_red['variety generic'].unique()
# Out:
# 318
# array(['Port', 'Sangiovese Grosso', 'Shiraz', 'Sangiovese', 'Carignan',
#        'Syrah', 'Pinot Noir', 'Cabernet Sauvignon',
#        'Tempranillo-Cabernet Sauvignon', 'Nebbiolo', 'Red Blend',
#        'Corvina, Rondinella, Molinara', 'Ramisco', 'Merlot', 'Tinto Fino',
#        'Portuguese Red', 'Tempranillo Blend', 'Malbec', 'Garnacha',
#        'Pinotage', 'Cabernet Blend', 'Pedro Ximénez', 'Tinta de Toro',
#        'Prugnolo Gentile', 'Carmenère', 'Grenache', 'Shiraz-Viognier',
#        'Nerello Mascalese', 'Gamay', 'Tinto del Pais', 'Tannat',
#        'Petit Verdot', 'Spätburgunder', 'Aglianico', 'Cabernet Franc',
#        'Malbec-Cabernet Sauvignon', 'Malbec-Cabernet', 'Francisa',
#        'Rosenmuskateller', 'Mission', 'Alicante Bouschet',
#        'Cabernet-Shiraz', 'Pinot Nero', 'Graciano', 'Petite Verdot',
#        'Pinot Meunier', 'Touriga Nacional Blend', 'Claret',
#        'Cabernet Sauvignon-Malbec', 'Mataro', 'Marzemino',
# ...

# %%
df_cleaning_red.loc[df_cleaning_red['variety generic'].str.contains('-', case=False), 'variety generic'] = 'Red Blend'
print(df_cleaning_red['variety generic'].nunique())
df_cleaning_red['variety generic'].unique()
# Out:
# 223
# array(['Port', 'Sangiovese Grosso', 'Shiraz', 'Sangiovese', 'Carignan',
#        'Syrah', 'Pinot Noir', 'Cabernet Sauvignon', 'Red Blend',
#        'Nebbiolo', 'Corvina, Rondinella, Molinara', 'Ramisco', 'Merlot',
#        'Tinto Fino', 'Portuguese Red', 'Tempranillo Blend', 'Malbec',
#        'Garnacha', 'Pinotage', 'Cabernet Blend', 'Pedro Ximénez',
#        'Tinta de Toro', 'Prugnolo Gentile', 'Carmenère', 'Grenache',
#        'Nerello Mascalese', 'Gamay', 'Tinto del Pais', 'Tannat',
#        'Petit Verdot', 'Spätburgunder', 'Aglianico', 'Cabernet Franc',
#        'Francisa', 'Rosenmuskateller', 'Mission', 'Alicante Bouschet',
#        'Pinot Nero', 'Graciano', 'Petite Verdot', 'Pinot Meunier',
#        'Touriga Nacional Blend', 'Claret', 'Mataro', 'Marzemino',
#        'Blaufränkisch', 'Sagrantino', 'Petite Sirah', 'Mencía',
#        'Tinta Negra Mole', 'Maturana', 'Mazuelo', 'Barbera', 'Zinfandel',
#        'Montepulciano', 'Negroamaro', 'Traminer', 'Dolcetto', 'Bobal',
# ...

# %%
other = ['Frappato', "Nero d'Avola", 'Primitivo', 'Gamay', 'Petit Verdot',
       'Monica', 'Sangiovese', 'Aglianico', 'Carmenère', 'Meritage', 'Nebbiolo', 'Barbera', 'Graciano',
       'Prugnolo Gentile',
       'Montepulciano', 'Mencía', 'Zweigelt',
       'Nerello Mascalese', 'Cannonau', 'Dolcetto',
       'Garnacha Tintorera', 'Pinotage', 'Früburgunder',
       'Cinsault', 'Monastrell', 'Corvina, Rondinella, Molinara', 'Port',
       'Roditis', 'Traminer', 'Sangiovese Grosso',
       'Negroamaro', 'Pinot Meunier', 'Teroldego', 'Tannat', 'Claret',
       'Baga', 'Alvarinho', 'Ruché', 'Tinta de Toro', 'Cesanese','Sémillon', 'Lagrein', 'Tinta Fina', 'St. Laurent',
       'Touriga Nacional', 'Pugnitello', 'Maturana', 'Blaufränkisch', 
       'Bonarda', 'Spätburgunder', 'Lemberger', 'Saperavi',
       'Mourvèdre', 'Dornfelder', 'Mondeuse', 'Perricone',
       'Pedro Ximénez', 'Agiorgitiko', 'Carignano', 'Aleatico',
       'Carcajolu', 'Tinto Fino', 'Magliocco', 'Marselan', 'Alfrocheiro',
       'Norton', 'Alicante Bouschet', 'Feteasca Neagra', 'Black Muscat',
       'Xinomavro', 'Charbono', 'Valdiguié',
       'Petite Verdot', 'Uva di Troia', 'Kalecik Karasi', 'Negrette',
       'Raboso', 'País', 'Sagrantino', 'Tinto del Pais', 'Carignan',
       'Marzemino', 'Castelão', 'Teran', 'Freisa', 'Nero di Troia',
       'Tinta Roriz', 'Trincadeira', 'Brachetto',
       'Argaman', 'Bobal', 'Touriga Franca',
       'Chambourcin', 'Prieto Picudo', 'Piedirosso', 'Moscatel Roxo',
       'Macabeo', 'Mazuelo', 'Tinta del Pais', 'Vranec', 'Corvina',
       'Mavrud', "Cesanese d'Affile", 'Duras',
       "Loin de l'Oeil", 'Tinta del Toro', 'Prunelard', 'Trepat',
       'Plavac Mali', 'Rufete', 'Mataro', 'Carignane',
       'Tinta Cao', 'Blauer Portugieser', 'Pinot Auxerrois', 'Groppello',
       'Poulsard', 'Carineña', 'Mavrodaphne', 'Sciaccerellu', 'Alicante',
       'Rosenmuskateller', 'Aragonez', 'Alvarelhão', 'Mavroudi',
       'Muscat Hamburg', 'Aragonês', 'Refosco', 'Tinto Velasco',
       'Kadarka', 'Incrocio Manzoni', 'Fer Servadou',
       'Mission', 'Braucol', 'Pallagrello Nero', 'Kekfrankos',
       'Vespolina', 'Susumaniello', 'Tamjanika', 'Trousseau', 
       'Rara Neagra', 'Molinara', 'Abouriou', 'Nerello Cappuccio',
       'Tinta Barroca', 'Okuzgozu', 'Vinhão', 'Souzao', 'Roter Traminer',
       'Counoise', 'Tinta Francisca', 'Muscadine', 'Ciliegiolo',
       'Canaiolo', 'Bombino Nero', 'Bovale', 'Frankovka', 'Nielluciu',
       'Grolleau', 'Jaen', 'Casavecchia', 'Vidadillo',
        'Cabernet Pfeffer', 'Babić', 'Gaglioppo',
       'Papaskarasi', 'Mandilaria', 'Teroldego Rotaliano', 'Albarossa',
       'Uvalino', 'Boğazkere', 'Tinta Amarela', 'Tinta Negra Mole',
       'Chelois', 'Marquette',  'Bastardo', 'Durif',
       'Rebo', 'St. Vincent', 'Chancellor', 'Premsal',
       'Centesimino', 'Ramisco', 'Mavrokalavryta',
       'Babosa Negro', 'Tintilia ', 'Listán Negro', 'Trollinger',
       'Tinta Miúda', 'Francisa', 'Tămâioasă Românească', 'Pignolo']

# %%
df_cleaning_red['variety generic'] = list(map(lambda x : 'Other Red' if any(item in x for item in other) else x, df_cleaning_red['variety generic']))
print(df_cleaning_red['variety generic'].nunique())
df_cleaning_red['variety generic'].unique()
# Out:
# 28
# array(['Other Red', 'Shiraz', 'Syrah', 'Pinot Noir', 'Cabernet Sauvignon',
#        'Red Blend', 'Merlot', 'Tempranillo Blend', 'Malbec', 'Garnacha',
#        'Cabernet Blend', 'Grenache', 'Cabernet Franc', 'Pinot Nero',
#        'Petite Sirah', 'Zinfandel', 'Malbec Blend', 'Grenache Blend',
#        'Cabernet Merlot', 'Other', 'Madeira Blend', 'Cabernet',
#        'Grenache Noir', 'Baco Noir', 'Garnacha Blend',
#        'Cabernet Sauvignon Grenache', 'Sauvignon Musqué',
#        'Cabernet Moravia'], dtype=object)

# %%
df_cleaning_red.loc[df_cleaning_red['variety generic'].str.contains('Blend', case=False), 'variety generic'] = 'Red Blend'
print(df_cleaning_red['variety generic'].nunique())
df_cleaning_red['variety generic'].unique()
# Out:
# 22
# array(['Other Red', 'Shiraz', 'Syrah', 'Pinot Noir', 'Cabernet Sauvignon',
#        'Red Blend', 'Merlot', 'Malbec', 'Garnacha', 'Grenache',
#        'Cabernet Franc', 'Pinot Nero', 'Petite Sirah', 'Zinfandel',
#        'Cabernet Merlot', 'Other', 'Cabernet', 'Grenache Noir',
#        'Baco Noir', 'Cabernet Sauvignon Grenache', 'Sauvignon Musqué',
#        'Cabernet Moravia'], dtype=object)

# %%
df_cleaning_red.loc[df_cleaning_red['variety generic'].str.contains('Noir', case=False), 'variety generic'] = 'Pinot Noir'
print(df_cleaning_red['variety generic'].nunique())
df_cleaning_red['variety generic'].unique()
# Out:
# 20
# array(['Other Red', 'Shiraz', 'Syrah', 'Pinot Noir', 'Cabernet Sauvignon',
#        'Red Blend', 'Merlot', 'Malbec', 'Garnacha', 'Grenache',
#        'Cabernet Franc', 'Pinot Nero', 'Petite Sirah', 'Zinfandel',
#        'Cabernet Merlot', 'Other', 'Cabernet',
#        'Cabernet Sauvignon Grenache', 'Sauvignon Musqué',
#        'Cabernet Moravia'], dtype=object)

# %%
df_cleaning_red.loc[df_cleaning_red['variety generic'].str.contains('Cabernet Sauvignon Grenache', case=False), 'variety generic'] = 'Red Blend'
print(df_cleaning_red['variety generic'].nunique())
df_cleaning_red['variety generic'].unique()
# Out:
# 19
# array(['Other Red', 'Shiraz', 'Syrah', 'Pinot Noir', 'Cabernet Sauvignon',
#        'Red Blend', 'Merlot', 'Malbec', 'Garnacha', 'Grenache',
#        'Cabernet Franc', 'Pinot Nero', 'Petite Sirah', 'Zinfandel',
#        'Cabernet Merlot', 'Other', 'Cabernet', 'Sauvignon Musqué',
#        'Cabernet Moravia'], dtype=object)

# %%
df_cleaning_red.loc[df_cleaning_red['variety generic'].str.contains('Cabernet Merlot', case=False), 'variety generic'] = 'Red Blend'
print(df_cleaning_red['variety generic'].nunique())
df_cleaning_red['variety generic'].unique()
# Out:
# 18
# array(['Other Red', 'Shiraz', 'Syrah', 'Pinot Noir', 'Cabernet Sauvignon',
#        'Red Blend', 'Merlot', 'Malbec', 'Garnacha', 'Grenache',
#        'Cabernet Franc', 'Pinot Nero', 'Petite Sirah', 'Zinfandel',
#        'Other', 'Cabernet', 'Sauvignon Musqué', 'Cabernet Moravia'],
#       dtype=object)

# %%
df_cleaning_red.loc[df_cleaning_red['variety generic'].str.contains('Pinot Nero', case=False), 'variety generic'] = 'Pinot Noir'
print(df_cleaning_red['variety generic'].nunique())
df_cleaning_red['variety generic'].unique()
# Out:
# 17
# array(['Other Red', 'Shiraz', 'Syrah', 'Pinot Noir', 'Cabernet Sauvignon',
#        'Red Blend', 'Merlot', 'Malbec', 'Garnacha', 'Grenache',
#        'Cabernet Franc', 'Petite Sirah', 'Zinfandel', 'Other', 'Cabernet',
#        'Sauvignon Musqué', 'Cabernet Moravia'], dtype=object)

# %%
df_cleaning_red.loc[df_cleaning_red['variety generic'].str.contains('Garnacha', case=False), 'variety generic'] = 'Grenache'
print(df_cleaning_red['variety generic'].nunique())
df_cleaning_red['variety generic'].unique()
# Out:
# 16
# array(['Other Red', 'Shiraz', 'Syrah', 'Pinot Noir', 'Cabernet Sauvignon',
#        'Red Blend', 'Merlot', 'Malbec', 'Grenache', 'Cabernet Franc',
#        'Petite Sirah', 'Zinfandel', 'Other', 'Cabernet',
#        'Sauvignon Musqué', 'Cabernet Moravia'], dtype=object)

# %%
df_cleaning_red.loc[df_cleaning_red['variety generic'].str.contains('Sauvignon Musqué', case=False), 'variety generic'] = 'Red Blend'
print(df_cleaning_red['variety generic'].nunique())
df_cleaning_red['variety generic'].unique()
# Out:
# 15
# array(['Other Red', 'Shiraz', 'Syrah', 'Pinot Noir', 'Cabernet Sauvignon',
#        'Red Blend', 'Merlot', 'Malbec', 'Grenache', 'Cabernet Franc',
#        'Petite Sirah', 'Zinfandel', 'Other', 'Cabernet',
#        'Cabernet Moravia'], dtype=object)

# %%
df_cleaning_red.loc[df_cleaning_red['variety generic'].str.contains('Cabernet Moravia', case=False), 'variety generic'] = 'Red Blend'
print(df_cleaning_red['variety generic'].nunique())
df_cleaning_red['variety generic'].unique()
# Out:
# 14
# array(['Other Red', 'Shiraz', 'Syrah', 'Pinot Noir', 'Cabernet Sauvignon',
#        'Red Blend', 'Merlot', 'Malbec', 'Grenache', 'Cabernet Franc',
#        'Petite Sirah', 'Zinfandel', 'Other', 'Cabernet'], dtype=object)

# %% [markdown]
# # Condense Variety Types White

# %%
# Import Wine Data
df_cleaning_white = pd.read_csv('data/wine_data_cleaned_with_color.csv')
df_cleaning_white.head()
# Out:
#       ID    country                                        description  \
# 0  89478    Austria  Wet earth, rain-wet stones, damp moss, wild sa...
# 1  36531   Portugal  This Port was “rescued” from the darkest reces...
# 2  41441   Portugal  This was a great vintage Port year, and this w...
# 3  88870      Italy  Biondi-Santi performs exceptionally well in el...
# 4  56953  Australia  This inky, embryonic wine deserves to be cella...
#
#                designation  points  price         province  \
# 0  Ried Loibenberg Smaragd      94   1100           Wachau
# 1        90-year Old Tawny      97   1000             Port
# 2           Colheita White      94    980             Port
# 3                  Riserva      94    900          Tuscany
# 4                   Grange      99    850  South Australia
#
#                                                title            variety  \
# 0  Emmerich Knoll 2013 Ried Loibenberg Smaragd Gr...   Grüner Veltliner
# ...

# %%
# Create dataframe of only whites
df_cleaning_white = df_cleaning_white[df_cleaning_white["Color"] != 'Red']
df_cleaning_white = df_cleaning_white[df_cleaning_white["Color"] != 'Blush']
df_cleaning_white.head()
# Out:
#        ID  country                                        description  \
# 0   89478  Austria  Wet earth, rain-wet stones, damp moss, wild sa...
# 7   36529   France  Pure Chardonnay from the walled vineyard in th...
# 12    347  Germany  Dusty, saffron-spiced earthiness is juxtaposed...
# 13  16522  Germany  With layers upon layers of spicy saffron, peac...
# 14  43650  Germany  Perfumed florals mingle curiously with deep, d...
#
#                                  designation  points  price   province  \
# 0                    Ried Loibenberg Smaragd      94   1100     Wachau
# 7        Clos du Mesnil Brut Blanc de Blancs      99    800  Champagne
# 12  Kiedrich Gräfenberg Trockenbeerenauslese      97    775   Rheingau
# 13  Kiedrich Gräfenberg Trockenbeerenauslese      98    775   Rheingau
# 14  Kiedrich Gräfenberg Trockenbeerenauslese      95    775   Rheingau
#
#                                                 title           variety  \
# ...

# %%
# duplicate 'variety column' 
df_cleaning_white['variety generic'] = df_cleaning_white ['variety']
df_cleaning_white.head()
# Out:
#        ID  country                                        description  \
# 0   89478  Austria  Wet earth, rain-wet stones, damp moss, wild sa...
# 7   36529   France  Pure Chardonnay from the walled vineyard in th...
# 12    347  Germany  Dusty, saffron-spiced earthiness is juxtaposed...
# 13  16522  Germany  With layers upon layers of spicy saffron, peac...
# 14  43650  Germany  Perfumed florals mingle curiously with deep, d...
#
#                                  designation  points  price   province  \
# 0                    Ried Loibenberg Smaragd      94   1100     Wachau
# 7        Clos du Mesnil Brut Blanc de Blancs      99    800  Champagne
# 12  Kiedrich Gräfenberg Trockenbeerenauslese      97    775   Rheingau
# 13  Kiedrich Gräfenberg Trockenbeerenauslese      98    775   Rheingau
# 14  Kiedrich Gräfenberg Trockenbeerenauslese      95    775   Rheingau
#
#                                                 title           variety  \
# ...

# %%
other = ['Gewürztraminer', 'Inzolia', 'Grillo', 'Petit Manseng', 'Vernaccia', 'Viognier',
       'Vermentino', 'Verdejo', 'Furmint', 'Grüner Veltliner', 'Muscat', 'Muscadelle',
       'Tempranillo', 'Cortese', 'Vidal', 'Verdelho', 'Moscato',
       'Marsanne', 'Scheurebe', 'Kerner', 'Glera', 'Garganega', 'Viura',
       'Torrontés', 'Antão Vaz', 'Verduzzo', 'Verdicchio', 'Silvaner',
       'Carricante', 'Sylvaner', 'Fiano', 'Roussanne', 'Avesso',
       'Muscat Blanc à Petits Grains', 'Greco', 'Trebbiano', 'Insolia',
       'Weissburgunder', 'Prié Blanc', 'Falanghina',
       'Pansa Blanca', 'Bical', 'Moscatel', 'Malvasia Bianca',
       'Gelber Muskateller', 'Turbiana', 'Malagousia', 'Assyrtiko',
       'Rieslaner', 'Traminette', 'Cerceal', 'Fernão Pires', 'Arinto',
       'Pecorino', 'Albanello', 'Friulano', 'Meritage', 'Blanc du Bois',
       'Colombard', 'Assyrtico', 'Albana',
       'Muskat', 'Moschofilero', 'Fumé Blanc', 'Encruzado', 'Torbato',
       'Pallagrello', 'Catarratto', 'Rotgipfler',
       'Malvasia', 'Kisi', 'Ribolla Gialla', 'Vidal Blanc',
       'Palomino', 'Nascetta', 'Siria', 'Feteascǎ Regalǎ',
       'Tocai Friulano', 'Seyval Blanc', 'Tokaji', 'Welschriesling',
       'Moscadello', 'Symphony', 'Cercial', 'Roter Veltliner',
       'Passerina', 'Arneis', 'Kangoun', 'Loureiro',
       'Gros and Petit Manseng', 'Jacquère', 'Clairette', 'Mauzac',
       'Diamond', 'Muscat Canelli', 'Neuburger', 'Auxerrois',
       'Muskat Ottonel', 'Hárslevelü', 'Rkatsiteli', 'Trousseau Gris', 'Zibibbo', 'Gros Manseng', 'Muskateller',
       'Aligoté', 'Muscat Blanc', 'Pallagrello Bianco',
       'Malvasia Istriana', 'Picpoul', 'Morillon', 'Tokay',
       'Piquepoul Blanc', 'Vitovska', 'Orange Muscat', 'Grauburgunder',
       'Vignoles', 'Durella', 'Picolit', 'Godello', 'Debit',
       'Verduzzo Friulano ', 'Treixadura', 'Chasselas', 'Coda di Volpe',
       'Manzoni', 'Tocai', "Muscat d'Alexandrie", 'Gros Plant', 'Sacy',
       'Ugni Blanc', 'Muscatel', 'Mantonico', 'Posip', 'Veltliner',
       'Grecanico', 'Madeleine Angevine', 'Tempranillo Blanco', 'Nuragus', 'Vilana', 'Narince', 'Doña Blanca',
       'Thrapsathiri', 'Cococciola', 'Romorantin', 'Bombino Bianco',
       'Savatiano', 'Rivaner', 'Chinuri', 'Moscato Giallo', 'Timorasso',
       'Nosiola', 'Códega do Larinho', 'Hondarrabi Zuri', 'Azal',
       'Moscatel Graúdo', 'Viosinho', 'Paralleda', 'Malvasia di Candia',
       'Malvar', 'Airen', 'Erbaluce',
       'Muscat of Alexandria', 'Grechetto', 'Vespaiolo', 'Aidani',
       'Greco Bianco', 'Moscatel de Alejandría', 'Rolle',
       'Malvasia Nera', 'Orangetraube', 'Altesse', 'Jacquez', 'Gouveio',
       'Elbling', 'Schwartzriesling',
       'Malagouzia', 'Sämling', 'Folle Blanche', 'Tamianka', 'Bual',
       'Rabigato', 'Sauvignonasse', 'Meseguera', 'Xinisteri',
       'Trebbiano di Lugana', 'Verdeca', 'Trebbiano Spoletino',
       'Gelber Traminer', 'Cayuga', 'Morio Muskat', 'Biancale',
       'Ansonica', 'Roviello', 'Nasco', 'Mtsvane', 'Apple', 'Feteasca',
       'Sercial', 'Pignoletto', 'Malvasia Fina', 'Jampal', 'Robola',
       'Picapoll', 'Tinta Madeira', 'Catalanesca', 'Zlahtina', 'Favorita',
       'Petit Courbu', 'Torontel', 'Caprettone', 'Athiri']

# %%
df_cleaning_white['variety generic'] = list(map(lambda x : 'Other White' if any(item in x for item in other) else x, df_cleaning_white['variety generic']))
print(df_cleaning_white['variety generic'].nunique())
df_cleaning_white['variety generic'].unique()
# Out:
# 52
# array(['Other White', 'Chardonnay', 'Riesling', 'Champagne Blend',
#        'White Blend', 'Rhône-style White Blend', 'Sparkling Blend',
#        'Bordeaux-style White Blend', 'Sherry', 'Pinot Bianco',
#        'Chenin Blanc', 'Sauvignon Blanc', 'Pinot Gris',
#        'Austrian white blend', 'Alsace white blend', 'Portuguese White',
#        'Sauvignon', 'Savagnin', 'Pinot Blanc', 'Sauvignon Blanc-Semillon',
#        'Semillon-Sauvignon Blanc', 'Melon', 'Albariño',
#        'Chardonnay-Pinot Blanc', 'Pinot Grigio', 'Garnacha Blanca',
#        'Provence white blend', 'Zierfandler', 'Müller-Thurgau',
#        'White Port', 'Riesling-Chardonnay', 'White Riesling',
#        'Grenache Blanc', 'Sauvignon Blanc-Chardonnay',
#        'Pinot Grigio-Sauvignon Blanc', 'Chardonnay-Albariño',
#        'Chardonnay-Semillon', 'Xarel-lo', 'Edelzwicker',
#        'Pinot Blanc-Chardonnay', 'Sauvignon Gris',
#        'Chenin Blanc-Chardonnay', 'Sauvignon Blanc-Chenin Blanc',
# ...

# %%
df_cleaning_white.loc[df_cleaning_white['variety generic'].str.contains('White Riesling', case=False), 'variety generic'] = 'Riesling'
print(df_cleaning_white['variety generic'].nunique())
df_cleaning_white['variety generic'].unique()
# Out:
# 51
# array(['Other White', 'Chardonnay', 'Riesling', 'Champagne Blend',
#        'White Blend', 'Rhône-style White Blend', 'Sparkling Blend',
#        'Bordeaux-style White Blend', 'Sherry', 'Pinot Bianco',
#        'Chenin Blanc', 'Sauvignon Blanc', 'Pinot Gris',
#        'Austrian white blend', 'Alsace white blend', 'Portuguese White',
#        'Sauvignon', 'Savagnin', 'Pinot Blanc', 'Sauvignon Blanc-Semillon',
#        'Semillon-Sauvignon Blanc', 'Melon', 'Albariño',
#        'Chardonnay-Pinot Blanc', 'Pinot Grigio', 'Garnacha Blanca',
#        'Provence white blend', 'Zierfandler', 'Müller-Thurgau',
#        'White Port', 'Riesling-Chardonnay', 'Grenache Blanc',
#        'Sauvignon Blanc-Chardonnay', 'Pinot Grigio-Sauvignon Blanc',
#        'Chardonnay-Albariño', 'Chardonnay-Semillon', 'Xarel-lo',
#        'Edelzwicker', 'Pinot Blanc-Chardonnay', 'Sauvignon Gris',
#        'Chenin Blanc-Chardonnay', 'Sauvignon Blanc-Chenin Blanc',
# ...

# %%
df_cleaning_white.loc[df_cleaning_white['variety generic'].str.contains('White_Blend', case=False), 'variety generic'] = 'White Blend'
print(df_cleaning_white['variety generic'].nunique())
df_cleaning_white['variety generic'].unique()
# Out:
# 51
# array(['Other White', 'Chardonnay', 'Riesling', 'Champagne Blend',
#        'White Blend', 'Rhône-style White Blend', 'Sparkling Blend',
#        'Bordeaux-style White Blend', 'Sherry', 'Pinot Bianco',
#        'Chenin Blanc', 'Sauvignon Blanc', 'Pinot Gris',
#        'Austrian white blend', 'Alsace white blend', 'Portuguese White',
#        'Sauvignon', 'Savagnin', 'Pinot Blanc', 'Sauvignon Blanc-Semillon',
#        'Semillon-Sauvignon Blanc', 'Melon', 'Albariño',
#        'Chardonnay-Pinot Blanc', 'Pinot Grigio', 'Garnacha Blanca',
#        'Provence white blend', 'Zierfandler', 'Müller-Thurgau',
#        'White Port', 'Riesling-Chardonnay', 'Grenache Blanc',
#        'Sauvignon Blanc-Chardonnay', 'Pinot Grigio-Sauvignon Blanc',
#        'Chardonnay-Albariño', 'Chardonnay-Semillon', 'Xarel-lo',
#        'Edelzwicker', 'Pinot Blanc-Chardonnay', 'Sauvignon Gris',
#        'Chenin Blanc-Chardonnay', 'Sauvignon Blanc-Chenin Blanc',
# ...

# %%
df_cleaning_white.loc[df_cleaning_white['variety generic'].str.contains('-', case=False), 'variety generic'] = 'White Blend'
print(df_cleaning_white['variety generic'].nunique())
df_cleaning_white['variety generic'].unique()
# Out:
# 28
# array(['Other White', 'Chardonnay', 'Riesling', 'Champagne Blend',
#        'White Blend', 'Sparkling Blend', 'Sherry', 'Pinot Bianco',
#        'Chenin Blanc', 'Sauvignon Blanc', 'Pinot Gris',
#        'Austrian white blend', 'Alsace white blend', 'Portuguese White',
#        'Sauvignon', 'Savagnin', 'Pinot Blanc', 'Melon', 'Albariño',
#        'Pinot Grigio', 'Garnacha Blanca', 'Provence white blend',
#        'Zierfandler', 'White Port', 'Grenache Blanc', 'Edelzwicker',
#        'Sauvignon Gris', 'Johannisberg Riesling'], dtype=object)

# %%
df_cleaning_white.loc[df_cleaning_white['variety generic'].str.contains('Johannisberg Riesling', case=False), 'variety generic'] = 'Riesling'
print(df_cleaning_white['variety generic'].nunique())
df_cleaning_white['variety generic'].unique()
# Out:
# 27
# array(['Other White', 'Chardonnay', 'Riesling', 'Champagne Blend',
#        'White Blend', 'Sparkling Blend', 'Sherry', 'Pinot Bianco',
#        'Chenin Blanc', 'Sauvignon Blanc', 'Pinot Gris',
#        'Austrian white blend', 'Alsace white blend', 'Portuguese White',
#        'Sauvignon', 'Savagnin', 'Pinot Blanc', 'Melon', 'Albariño',
#        'Pinot Grigio', 'Garnacha Blanca', 'Provence white blend',
#        'Zierfandler', 'White Port', 'Grenache Blanc', 'Edelzwicker',
#        'Sauvignon Gris'], dtype=object)

# %%
df_cleaning_white.loc[df_cleaning_white['variety generic'].str.contains('Savagnin', case=False), 'variety generic'] = 'Sauvignon'
print(df_cleaning_white['variety generic'].nunique())
df_cleaning_white['variety generic'].unique()
# Out:
# 26
# array(['Other White', 'Chardonnay', 'Riesling', 'Champagne Blend',
#        'White Blend', 'Sparkling Blend', 'Sherry', 'Pinot Bianco',
#        'Chenin Blanc', 'Sauvignon Blanc', 'Pinot Gris',
#        'Austrian white blend', 'Alsace white blend', 'Portuguese White',
#        'Sauvignon', 'Pinot Blanc', 'Melon', 'Albariño', 'Pinot Grigio',
#        'Garnacha Blanca', 'Provence white blend', 'Zierfandler',
#        'White Port', 'Grenache Blanc', 'Edelzwicker', 'Sauvignon Gris'],
#       dtype=object)

# %%
df_cleaning_white.loc[df_cleaning_white['variety generic'].str.contains('Edelzwicker', case=False), 'variety generic'] = 'Other White'
print(df_cleaning_white['variety generic'].nunique())
df_cleaning_white['variety generic'].unique()
# Out:
# 25
# array(['Other White', 'Chardonnay', 'Riesling', 'Champagne Blend',
#        'White Blend', 'Sparkling Blend', 'Sherry', 'Pinot Bianco',
#        'Chenin Blanc', 'Sauvignon Blanc', 'Pinot Gris',
#        'Austrian white blend', 'Alsace white blend', 'Portuguese White',
#        'Sauvignon', 'Pinot Blanc', 'Melon', 'Albariño', 'Pinot Grigio',
#        'Garnacha Blanca', 'Provence white blend', 'Zierfandler',
#        'White Port', 'Grenache Blanc', 'Sauvignon Gris'], dtype=object)

# %%
df_cleaning_white.loc[df_cleaning_white['variety generic'].str.contains('Champagne Blend', case=False), 'variety generic'] = 'Champagne'
print(df_cleaning_white['variety generic'].nunique())
df_cleaning_white['variety generic'].unique()
# Out:
# 25
# array(['Other White', 'Chardonnay', 'Riesling', 'Champagne',
#        'White Blend', 'Sparkling Blend', 'Sherry', 'Pinot Bianco',
#        'Chenin Blanc', 'Sauvignon Blanc', 'Pinot Gris',
#        'Austrian white blend', 'Alsace white blend', 'Portuguese White',
#        'Sauvignon', 'Pinot Blanc', 'Melon', 'Albariño', 'Pinot Grigio',
#        'Garnacha Blanca', 'Provence white blend', 'Zierfandler',
#        'White Port', 'Grenache Blanc', 'Sauvignon Gris'], dtype=object)

# %%
df_cleaning_white.loc[df_cleaning_white['variety generic'].str.contains('blend', case=False), 'variety generic'] = 'White Blend'
print(df_cleaning_white['variety generic'].nunique())
df_cleaning_white['variety generic'].unique()
# Out:
# 21
# array(['Other White', 'Chardonnay', 'Riesling', 'Champagne',
#        'White Blend', 'Sherry', 'Pinot Bianco', 'Chenin Blanc',
#        'Sauvignon Blanc', 'Pinot Gris', 'Portuguese White', 'Sauvignon',
#        'Pinot Blanc', 'Melon', 'Albariño', 'Pinot Grigio',
#        'Garnacha Blanca', 'Zierfandler', 'White Port', 'Grenache Blanc',
#        'Sauvignon Gris'], dtype=object)

# %%
df_cleaning_white.loc[df_cleaning_white['variety generic'].str.contains('Albariño', case=False), 'variety generic'] = 'Other White'
print(df_cleaning_white['variety generic'].nunique())
df_cleaning_white['variety generic'].unique()
# Out:
# 20
# array(['Other White', 'Chardonnay', 'Riesling', 'Champagne',
#        'White Blend', 'Sherry', 'Pinot Bianco', 'Chenin Blanc',
#        'Sauvignon Blanc', 'Pinot Gris', 'Portuguese White', 'Sauvignon',
#        'Pinot Blanc', 'Melon', 'Pinot Grigio', 'Garnacha Blanca',
#        'Zierfandler', 'White Port', 'Grenache Blanc', 'Sauvignon Gris'],
#       dtype=object)

# %%
df_cleaning_white.loc[df_cleaning_white['variety generic'].str.contains('Garnacha Blanca', case=False), 'variety generic'] = 'Grenache Blanc'
print(df_cleaning_white['variety generic'].nunique())
df_cleaning_white['variety generic'].unique()
# Out:
# 19
# array(['Other White', 'Chardonnay', 'Riesling', 'Champagne',
#        'White Blend', 'Sherry', 'Pinot Bianco', 'Chenin Blanc',
#        'Sauvignon Blanc', 'Pinot Gris', 'Portuguese White', 'Sauvignon',
#        'Pinot Blanc', 'Melon', 'Pinot Grigio', 'Grenache Blanc',
#        'Zierfandler', 'White Port', 'Sauvignon Gris'], dtype=object)

# %%
df_cleaning_white.loc[df_cleaning_white['variety generic'].str.contains('White Port', case=False), 'variety generic'] = 'Other White'
print(df_cleaning_white['variety generic'].nunique())
df_cleaning_white['variety generic'].unique()
# Out:
# 18
# array(['Other White', 'Chardonnay', 'Riesling', 'Champagne',
#        'White Blend', 'Sherry', 'Pinot Bianco', 'Chenin Blanc',
#        'Sauvignon Blanc', 'Pinot Gris', 'Portuguese White', 'Sauvignon',
#        'Pinot Blanc', 'Melon', 'Pinot Grigio', 'Grenache Blanc',
#        'Zierfandler', 'Sauvignon Gris'], dtype=object)

# %% [markdown]
# # Condense Variety Types Blush

# %%
# Import Wine Data
df_cleaning_blush = pd.read_csv('data/wine_data_cleaned_with_color.csv')
df_cleaning_blush.head()
# Out:
#       ID    country                                        description  \
# 0  89478    Austria  Wet earth, rain-wet stones, damp moss, wild sa...
# 1  36531   Portugal  This Port was “rescued” from the darkest reces...
# 2  41441   Portugal  This was a great vintage Port year, and this w...
# 3  88870      Italy  Biondi-Santi performs exceptionally well in el...
# 4  56953  Australia  This inky, embryonic wine deserves to be cella...
#
#                designation  points  price         province  \
# 0  Ried Loibenberg Smaragd      94   1100           Wachau
# 1        90-year Old Tawny      97   1000             Port
# 2           Colheita White      94    980             Port
# 3                  Riserva      94    900          Tuscany
# 4                   Grange      99    850  South Australia
#
#                                                title            variety  \
# 0  Emmerich Knoll 2013 Ried Loibenberg Smaragd Gr...   Grüner Veltliner
# ...

# %%
# Create dataframe of only Blush
df_cleaning_blush = df_cleaning_blush[df_cleaning_blush["Color"] != 'Red']
df_cleaning_blush = df_cleaning_blush[df_cleaning_blush["Color"] != 'White']
df_cleaning_blush.head()
# Out:
#          ID country                                        description  \
# 8     97150  France  Soft Pinot Noir gives this warm, rounded wine....
# 951   26891      US  This is a beautiful, complex and complete wine...
# 2761   9396  France  Always aged for a year before it is released, ...
# 2810  17981  France  This is a serious wine with a lighter brighter...
# 2956  56762  France  This is toasty and vanilla-laden, but stands o...
#
#      designation  points  price      province  \
# 8       Morogues      87    800  Loire Valley
# 951    J. Schram      96    150    California
# 2761      Garrus      93    100      Provence
# 2810      Garrus      94    100      Provence
# 2956      Garrus      90    100      Provence
#
#                                                   title variety  \
# 8      Domaine Pellé 2014 Morogues Rosé (Menetou-Salon)    Rosé
# 951       Schramsberg 2008 J. Schram Rosé (North Coast)    Rosé
# ...

# %%
df_cleaning_blush['variety generic'] = df_cleaning_blush ['variety']
df_cleaning_blush.head()
# Out:
#          ID country                                        description  \
# 8     97150  France  Soft Pinot Noir gives this warm, rounded wine....
# 951   26891      US  This is a beautiful, complex and complete wine...
# 2761   9396  France  Always aged for a year before it is released, ...
# 2810  17981  France  This is a serious wine with a lighter brighter...
# 2956  56762  France  This is toasty and vanilla-laden, but stands o...
#
#      designation  points  price      province  \
# 8       Morogues      87    800  Loire Valley
# 951    J. Schram      96    150    California
# 2761      Garrus      93    100      Provence
# 2810      Garrus      94    100      Provence
# 2956      Garrus      90    100      Provence
#
#                                                   title variety  \
# 8      Domaine Pellé 2014 Morogues Rosé (Menetou-Salon)    Rosé
# 951       Schramsberg 2008 J. Schram Rosé (North Coast)    Rosé
# ...

# %%
print(df_cleaning_blush['variety generic'].nunique())
# Out:
# 15

# %%
df_cleaning_blush.loc[df_cleaning_blush['variety'].str.contains('Rose', case=False), 'variety generic'] = 'Rosé'
print(df_cleaning_blush['variety generic'].nunique())
df_cleaning_blush['variety generic'].unique()
# Out:
# 14
# array(['Rosé', 'Portuguese Sparkling', 'Portuguese Rosé', 'Rosato',
#        'Moscato Rosa', 'Lambrusco di Sorbara', 'Rosado',
#        'Lambrusco Grasparossa', 'Schiava', 'Lambrusco',
#        'Lambrusco Salamino', 'Sideritis', 'Çalkarası', 'Gragnano'],
#       dtype=object)

# %%
df_cleaning_blush.loc[df_cleaning_blush['variety'].str.contains('Rosato', case=False), 'variety generic'] = 'Rosé'
print(df_cleaning_blush['variety generic'].nunique())
df_cleaning_blush['variety generic'].unique()
# Out:
# 13
# array(['Rosé', 'Portuguese Sparkling', 'Portuguese Rosé', 'Moscato Rosa',
#        'Lambrusco di Sorbara', 'Rosado', 'Lambrusco Grasparossa',
#        'Schiava', 'Lambrusco', 'Lambrusco Salamino', 'Sideritis',
#        'Çalkarası', 'Gragnano'], dtype=object)

# %%
df_cleaning_blush.loc[df_cleaning_blush['variety'].str.contains('Rosado', case=False), 'variety generic'] = 'Rosé'
print(df_cleaning_blush['variety generic'].nunique())
df_cleaning_blush['variety generic'].unique()
# Out:
# 12
# array(['Rosé', 'Portuguese Sparkling', 'Portuguese Rosé', 'Moscato Rosa',
#        'Lambrusco di Sorbara', 'Lambrusco Grasparossa', 'Schiava',
#        'Lambrusco', 'Lambrusco Salamino', 'Sideritis', 'Çalkarası',
#        'Gragnano'], dtype=object)

# %% [markdown]
# # Append dataframes

# %%
# append red, white, and blush dataframes together
df_cleaned_final = df_cleaning_red.append(df_cleaning_white, ignore_index=True)
df_cleaned_final = df_cleaned_final.append(df_cleaning_blush, ignore_index=True)
df_cleaned_final.head()
# Out:
#       ID    country                                        description  \
# 0  36531   Portugal  This Port was “rescued” from the darkest reces...
# 1  41441   Portugal  This was a great vintage Port year, and this w...
# 2  88870      Italy  Biondi-Santi performs exceptionally well in el...
# 3  56953  Australia  This inky, embryonic wine deserves to be cella...
# 4  77028  Australia  This has all the size and weight you've come t...
#
#          designation  points  price         province  \
# 0  90-year Old Tawny      97   1000             Port
# 1     Colheita White      94    980             Port
# 2            Riserva      94    900          Tuscany
# 3             Grange      99    850  South Australia
# 4             Grange      98    850  South Australia
#
#                                                title            variety  \
# 0      W. & J. Graham's NV 90-year Old Tawny  (Port)               Port
# ...

# %% [markdown]
# # Change column names

# %%
# rename columns
df_cleaned_final = df_cleaned_final.rename(columns={"variety": "variety (specific)", "variety generic": "variety"})

# %%
df_cleaned_final.variety.nunique()
# Out:
# 44

# %% [markdown]
# # Export to csv

# %%
# export final cleaned file to csv
df_cleaned_final.to_csv('data/wine_data_cleaned_final.csv', index=False)
df_cleaned_final
# Out:
#            ID    country                                        description  \
# 0       36531   Portugal  This Port was “rescued” from the darkest reces...
# 1       41441   Portugal  This was a great vintage Port year, and this w...
# 2       88870      Italy  Biondi-Santi performs exceptionally well in el...
# 3       56953  Australia  This inky, embryonic wine deserves to be cella...
# 4       77028  Australia  This has all the size and weight you've come t...
# 5       56959  Australia  Is this the Yin to Grange's Yang? The wines ar...
# 6      108484      Italy  Thanks to having some of the highest vineyards...
# 7       78235   Portugal  Sweet, surprisingly soft for its age, this sho...
# 8       39627  Australia  This wine is rather developed, showing leather...
# 9       15846      Spain  This single-vineyard Carignan is living proof ...
# 10      90583   Portugal  While this wine from a year that was not decla...
# ...
